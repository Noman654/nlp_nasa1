# %%
import get_data as gt

# %%
gt.get_resources()
# Out:
# Cleaning and Tokenizing...

# %%
gt.search_similar_research("Thermodynamics and heat")
# Out:
#    Relevance                                              Title  \
# 0      66.63  SHOCK-WAVE PROFILES OVER ELLIPSOIDAL-NOSED BOD...
# 1      66.63  REGARDING THE EFFECTS OF RELAXATION RATE ON HE...
# 2      66.28  CREW PHYSICAL SUPPORT AND RESTRAINT IN ADVANCE...
# 3      66.26  Surveys of the oxygen multiplets lambda 7774 a...
# 4      61.08  The thermal control problem for lunar vehicles...
#
#               category                                      research Plot
# 0         ['AIRCRAFT']  Shock-wave profiles over ellipsoidal-nosed bod...
# 1       ['NAVIGATION']  Relaxation rate effects on heat conduction in ...
# 2      ['METEOROLOGY']  Supports and restraints for crews in advanced ...
# 3  ['SPACE RADIATION']  Lambda 7774 and 8446 oxygen multiplets in sola...
# 4   ['SPACE VEHICLES']  Computer program for thermal control of lunar ...

# %%
# Out:
#        Unnamed: 0           id  \
# 0               0  19930091025
# 1               1  19930091050
# 2               2  20030082190
# 3               3  19930080719
# 4               4  19630040348
# ...           ...          ...
# 17290       17290  19660038797
# 17291       17291  19660038799
# 17292       17292  19660038801
# 17293       17293  19660038855
# 17294       17294  19660038860
#
#                                                    title  \
# 0      Annual Report of the National Advisory Committ...
# 1                  Aeronautic Power Plant Investigations
# 2                             Theory of Lifting Surfaces
# 3      On the Elementary Relation Between Pitch, Slip...
# 4      Design of Wind Tunnels and Wind Tunnel Propell...
# ...                                                  ...
# 17290  Observations of the geomagnetic cavity boundar...
# 17291          Ionospheric research from space vehicles.
# 17292  The National Aeronautics and Space Administrat...
# ...
